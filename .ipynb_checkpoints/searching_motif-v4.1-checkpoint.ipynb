# %%
# Searching a motif within the mic channel of a .kwd file
# the i-th motiff is in the file pattern_i.wav
# the raw data comes in file experiment.raw.kwd

# Definitions and functions

# %matplotlib inline
import pdb
import sys
import pandas as pd
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import matplotlib
import scipy.signal as sg
import math
import scipy as sp
import socket
import os
import wave
import struct
import h5py
from scipy.signal import hilbert
from scipy.stats import pearsonr
from scipy.io import wavfile
from scipy.signal import spectrogram
from basic_viewing import h5_functions as h5
import logging
import threading
from IPython.display import display
matplotlib.style.use('ggplot')
import yaml


class chunkFunction():
    def __init__(self, chunk, function, *args, **kwargs):
        print args
        self.chunk = chunk
        self.func = function
        self.args = args
        self.kwargs = kwargs

    def start(self):
        logger.info('Starting function {0}'.format(self.func.func_name))
#         for arg in self.args:
#             logger.debug() arg
#         for key, arg in self.kwargs.iteritems():
#             print key
#             print arg
        self.chunk.apply_filter(self.func, *self.args, **self.kwargs)
        logger.info('done')

class threadFunction():
    def __init__(self, function, *args, **kwargs):
        self.func = function
        self.args = args
        self.kwargs = kwargs
        self.out = None

    def run(self):
        logger.info('Starting function {0}'.format(self.func.func_name))
        for arg in self.args:
            print arg
        for key, arg in self.kwargs.iteritems():
            print key
            print arg
        self.out = self.func(*self.args, **self.kwargs)
        logger.info("done")

# Check wich computer to decide where the things are mounted
comp_name=socket.gethostname()
print 'Computer: ' + comp_name

if 'txori' in comp_name or 'passaro' in comp_name or 'lintu' in comp_name:
    repos_folder = os.path.abspath('/mnt/cube/earneodo/repos')
    experiment_folder = os.path.join('/mnt/cube/earneodo/bci_zf/')

sys.path.append(os.path.join(repos_folder, 'soundflow', 'sound_tools'))
sys.path.append(os.path.join(repos_folder, 'ephysflow'))
sys.path.append(os.path.join(repos_folder, 'analysis-tools'))

#imports after setting the paths
import soundtools as st
import Kwik as oe
from file_tools import experiment as et


#setup the data folder
ss_data_folder = os.path.join(experiment_folder, 'ss_data')
# Out:
# Computer: passaro

# %%
# User Parameters
bird_id = 'z017'
sess = 'day-2016-06-23' #day of recording

# print the list of recs in the file
fn = et.file_names(bird_id, sess, 0)
sess_file_path = os.path.join(fn['folders']['ss'], fn['files']['ss_raw'])
sess_file = h5py.File(sess_file_path, 'r')
sess_file['recordings'].keys()
# Out:
# [u'0', u'1', u'2', u'3', u'4']

# %%
# prepare files for reading the stream/writing the timestamps
pattern = 1

exp_par = et.get_parameters(bird_id, sess, 0)
search_pars = exp_par['search_motiff']
cand_file_path = et.file_path(fn, 'ss', 'cand')

# get the sound and the pattern
# read a bout from a wave file and prepare the templates 
pattern_name = 'motiff_' + str(pattern) + '.wav'
stim_path = et.file_names(bird_id)['folders']['stim']
pattern_path = os.path.join(stim_path, pattern_name)

pattern_sound = st.WavData2(pattern_path)
s_f = pattern_sound.s_f

# Program parameters:
#filte
filt_lo = search_pars['filt_lo'] #Hz
filt_hi = search_pars['filt_hi'] #Hz
# sonogram 
n_window = search_pars['n_window']
n_overlap = search_pars['n_overlap']
sigma = search_pars['sigma_factor']*s_f
#template match
window_env = search_pars['window_env']

#make the filter for the data file
#The band where we expect most of the energy of zf song to be in
hp_b, hp_a = sg.butter(4, filt_hi/(s_f/2.), btype='high')
lp_b, lp_a = sg.butter(4, filt_lo/(s_f/2.), btype='low')


# Plot the pattern to search
f_cut = 10000
pattern_chunk = st.Chunk(pattern_sound)
pattern_chunk.apply_filter(st.bandpass_filter, s_f)
plt.plot((pattern_chunk.data))
pattern_envelope = st.envelope(pattern_chunk.data[:,0], window=window_env)
plt.figure()
plt.plot(pattern_envelope)
pattern_spectrogram = spectrogram(pattern_chunk.data[:,0], s_f, 
                                  nperseg = n_window, 
                                  noverlap=n_overlap, 
                                  window = sg.gaussian(n_window, sigma), 
                                  scaling='spectrum')

plt.figure()
plt.pcolormesh(pattern_spectrogram[1], 
               pattern_spectrogram[0][pattern_spectrogram[0] < f_cut], 
               np.log(pattern_spectrogram[2][pattern_spectrogram[0] < f_cut, :]))

# %%
rec = 4 #recording group
fn = et.file_names(bird_id, sess, rec)
cand_grp = '/pattern_{0}/{1}'.format(pattern, rec)

mic_file_path = et.file_path(fn, 'ss', 'mic')
log_file_path = os.path.join(fn['folders']['ss'], 'search-motiff_{0:02}.log'.format(pattern, rec))
# create logger with 'spam_application'
logger = logging.getLogger('searching_motiff_v4')
logger.setLevel(logging.DEBUG)
# create file handler which logs even debug messages
fh = logging.FileHandler(log_file_path)
fh.setLevel(logging.DEBUG)
# create console handler with a higher log level
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fh.setFormatter(formatter)
ch.setFormatter(formatter)
# add the handlers to the logger
logger.addHandler(fh)
logger.addHandler(ch)

rms_thresh = search_pars['rms_threshold']

# Read just the audio channel from the table
logger.info('Loading the data from rec {}'.format(rec))
# audio_slice = h5.load_table_slice(data_table, np.arange(0, data_table.shape[0]), [chan_number])
# chan_sound = st.DatSoundCompat(st.bandpass_filter(audio_slice[:,0], chan_sf, filt_hi, filt_lo),
#                                      chan_sf, data_type=np.float)

chan_sound = st.WavData2(mic_file_path)

logger.info('{} samples loaded'.format(chan_sound.n_samples))
#start a thread to find the song
task_find_happy_song = threadFunction(st.find_happy_song, chan_sound, pattern_chunk, search_pars,
                                     cand_file_path = cand_file_path,
                                     cand_grp = cand_grp)
threads = []
t = threading.Thread(name= 'task_find_happy_song', 
                     target=task_find_happy_song.run)
threads.append(t)

t.start()            
logger.info('find_happy_song started')
# Out:
# 2016-07-25 12:21:50,890 - searching_motiff_v4 - INFO - Loading the data from rec 4
# 2016-07-25 12:21:50,965 - searching_motiff_v4 - INFO - 386340900 samples loaded
# 2016-07-25 12:21:50,967 - searching_motiff_v4 - INFO - Starting function find_happy_song
# 2016-07-25 12:21:50,967 - searching_motiff_v4 - INFO - find_happy_song started
# <soundtools.WavData2 instance at 0x7f7cb04a27e8>
# <soundtools.Chunk instance at 0x7f7cb4fbc5a8>
# {'sigma_factor': 0.001, 'filt_lo': 10000, 'onset_resolution': 1, 'motiff_patterns': {'motiff_1': 'motiff_1.wav'}, 'rolling_method': 'pandas', 'corr_thresh': 0.85, 'window_env': 500, 'filt_hi': 400, 'n_overlap': 192, 'n_window': 256, 'rms_threshold': 1.5}
# cand_file_path
# /mnt/cube/earneodo/bci_zf/ss_data/z017/day-2016-06-23/experiment.mot.h5
# cand_grp
# /pattern_1/4

# %%
t.isAlive()
# Out:
# True
# /mnt/cube/earneodo/repos/soundflow/sound_tools/soundtools.py:360: RuntimeWarning: invalid value encountered in greater
#   max_pos = np.where((a > 0) & (b > 0) & (c > threshold))[0]
# /usr/local/anaconda/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '4'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# 2016-07-26 02:57:28,500 - searching_motiff_v4 - INFO - done

# %%
# create logger with 'spam_application'
logger = logging.getLogger('searching_motiff_v4')
logger.setLevel(logging.DEBUG)
# create file handler which logs even debug messages
# create console handler with a higher log level
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
ch.setFormatter(formatter)
# add the handlers to the logger
logger.addHandler(ch)

# %%
def search_pattern(bird_id, sess, rec, pattern_chunk):
    logger.info('Configuring search for rec {}'.format(rec))
    fn = et.file_names(bird_id, sess, rec)
    mic_file_path = et.file_path(fn, 'ss', 'mic')
    logger.info('Loading the data from rec {}'.format(rec))
    chan_sound = st.WavData2(mic_file_path)
    logger.info('{} samples loaded'.format(chan_sound.n_samples))
    logger.info('Calling find_happy_song')
    
    exp_par = et.get_parameters(bird_id, sess, 0)
    search_pars = exp_par['search_motiff']
    cand_file_path = et.file_path(fn, 'ss', 'cand')
    cand_grp = '/pattern_{0}/{1}'.format(pattern, rec)

    candidates = st.find_happy_song(chan_sound, pattern_chunk, search_pars,
                      cand_file_path=cand_file_path,
                      cand_grp=cand_grp)
    logger.info('Found {} candidates'.format(candidates.index.size))
    return candidates

def search_pattern_all_rec(bird_id, sess, pattern_chunk):
    exp_par = et.get_parameters(bird_id, sess, 0)
    rec_list = get_rec_list(bird_id, sess)
    fn = et.file_names(bird_id, sess, 0)
    logger.info('Going to search for the motif in {} recs:'.format(len(rec_list)))
    rec_candidates = map(lambda x: search_pattern(bird_id, sess, int(x), pattern_chunk), 
                         rec_list)
    return rec_candidates
    
search_pattern_all_rec(bird_id, sess, pattern_chunk)
# Out:
# 2016-07-19 14:42:27,802 - searching_motiff_v4 - INFO - Going to search for the motif in 9 recs:
# 2016-07-19 14:42:27,803 - searching_motiff_v4 - INFO - Configuring search for rec 0
# 2016-07-19 14:42:27,804 - searching_motiff_v4 - INFO - Loading the data from rec 0
# 2016-07-19 14:42:27,872 - searching_motiff_v4 - INFO - 285664200 samples loaded
# 2016-07-19 14:42:27,873 - searching_motiff_v4 - INFO - Calling find_happy_song
# /usr/local/anaconda/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '0'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# 2016-07-20 11:10:42,807 - searching_motiff_v4 - INFO - Found 157 candidates
# 2016-07-20 11:10:42,809 - searching_motiff_v4 - INFO - Configuring search for rec 1
# 2016-07-20 11:10:42,818 - searching_motiff_v4 - INFO - Loading the data from rec 1
# 2016-07-20 11:10:42,857 - searching_motiff_v4 - INFO - 1748700 samples loaded
# 2016-07-20 11:10:42,858 - searching_motiff_v4 - INFO - Calling find_happy_song
# /usr/local/anaconda/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# 2016-07-20 11:26:22,971 - searching_motiff_v4 - INFO - Found 4 candidates
# 2016-07-20 11:26:22,972 - searching_motiff_v4 - INFO - Configuring search for rec 2
# 2016-07-20 11:26:22,973 - searching_motiff_v4 - INFO - Loading the data from rec 2
# 2016-07-20 11:26:23,040 - searching_motiff_v4 - INFO - 67259400 samples loaded
# 2016-07-20 11:26:23,040 - searching_motiff_v4 - INFO - Calling find_happy_song
# /usr/local/anaconda/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: '2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# 2016-07-20 15:59:53,809 - searching_motiff_v4 - INFO - Found 49 candidates
# 2016-07-20 15:59:53,810 - searching_motiff_v4 - INFO - Configuring search for rec 3
# 2016-07-20 15:59:53,811 - searching_motiff_v4 - INFO - Loading the data from rec 3
# 2016-07-20 15:59:53,892 - searching_motiff_v4 - INFO - 532352100 samples loaded
# 2016-07-20 15:59:53,893 - searching_motiff_v4 - INFO - Calling find_happy_song
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-b35d8b107df0> in <module>()
#      28     return rec_candidates
#      29
# ---> 30 search_pattern_all_rec(bird_id, sess, pattern_chunk)
#
# <ipython-input-22-b35d8b107df0> in search_pattern_all_rec(bird_id, sess, pattern_chunk)
#      25     logger.info('Going to search for the motif in {} recs:'.format(len(rec_list)))
#      26     rec_candidates = map(lambda x: search_pattern(bird_id, sess, int(x), pattern_chunk),
# ---> 27                          rec_list)
#      28     return rec_candidates
#      29
#
# <ipython-input-22-b35d8b107df0> in <lambda>(x)
#      24     fn = et.file_names(bird_id, sess, 0)
#      25     logger.info('Going to search for the motif in {} recs:'.format(len(rec_list)))
# ---> 26     rec_candidates = map(lambda x: search_pattern(bird_id, sess, int(x), pattern_chunk),
#      27                          rec_list)
#      28     return rec_candidates
#
# <ipython-input-22-b35d8b107df0> in search_pattern(bird_id, sess, rec, pattern_chunk)
#      15     candidates = st.find_happy_song(chan_sound, pattern_chunk, search_pars,
#      16                       cand_file_path=cand_file_path,
# ---> 17                       cand_grp=cand_grp)
#      18     logger.info('Found {} candidates'.format(candidates.index.size))
#      19     return candidates
#
# /mnt/cube/earneodo/repos/soundflow/sound_tools/soundtools.pyc in find_happy_song(chan_sound, pattern_chunk, search_pars, cand_file_path, cand_grp)
#     556                                          rms_threshold=rms_thresh,
#     557                                          window_step=onset_resolution,
# --> 558                                          rolling_method=rolling_method)
#     559
#     560     offset = pattern_chunk.samples if rolling_method is 'pandas' else 0
#
# /mnt/cube/earneodo/repos/soundflow/sound_tools/soundtools.pyc in match_by_envelope(full_sound, pattern, window_size, corr_thresh, rms_threshold, window_step, rolling_method)
#     406         logger.info('Will use function find_envelope_pandas')
#     407         find_envelope = find_envelope_pandas
# --> 408         sound_search = Chunk(full_sound).data[:, 0]
#     409
#     410     if rms_threshold is not None:
#
# /mnt/cube/earneodo/repos/soundflow/sound_tools/soundtools.pyc in __init__(self, sound, chan_list, segment)
#     208
#     209         # Read the data
# --> 210         self.data = sound.get_chunk(self.start, self.end, chan_list=chan_list)
#     211
#     212     def apply_filter(self, filter_func, *args, **kwargs):
#
# /mnt/cube/earneodo/repos/soundflow/sound_tools/soundtools.pyc in get_chunk(self, start, end, chan_list)
#      44         # TODO: this is dirty, change by one read, unpack and reshape
#      45         data = np.zeros((end - start, len(chan_list)), dtype=np.dtype(data_type))
# ---> 46         data_unpacked = struct.unpack('<' + str((end - start) * n_chans) + data_type, chunk_bit)
#      47         for i, channel in enumerate(chan_list):
#      48             data[:, i] = data_unpacked[channel::n_chans]
#
# MemoryError:

# %%
def open_kwd(bird, sess, location='ss'):
    fn = et.file_names(bird_id, sess, 0)
    kwd_file_file_path = et.file_path(fn, 'ss', 'ss_raw')
    kwd_file = h5py.File(kwd_file_file_path, 'r')
    return kwd_file
    
def get_rec_list(bird, sess, location='ss'):
    kwd_file = open_kwd(bird, sess, location)
    rec_list = kwd_file['/recordings'].keys()
    kwd_file.close()
    return rec_list
    
get_rec_list(bird_id, sess)
# Out:
# [u'0', u'1', u'2', u'3', u'4', u'5', u'6', u'7', u'8']

# %%
spectrogram_kwargs = {'nperseg': n_window,
                      'noverlap': n_overlap,
                      'window': sg.gaussian(n_window, sigma),
                      'scaling': 'spectrum'}

# %%
motif_start = 0
series = chan_sound.get_chunk(motif_start, motif_start + pattern_chunk.samples)
spectrogram_diff(series[:, 0],
              pattern_spectrogram[2],
              s_f,
              spectrogram_kwargs)
# Out:
# 0.83768392395107505

# %%
#aftermath:
#read the result
cand_file = pd.HDFStore(cand_file_path)
result = cand_file[cand_grp]
#read the sound channel from the file
audio_slice = h5.load_table_slice(data_table, np.arange(0, data_table.shape[0]), [chan_number])
chan_sound = st.DatSoundCompat(st.bandpass_filter(audio_slice[:,0], chan_sf, filt_hi, filt_lo),
                                     chan_sf, data_type=np.float)

# %%
cand_file = pd.HDFStore(cand_file_path)
result = cand_file[cand_grp]

# %%
all_candidates = result[result['bout']==True].sort_values('spectral_diff').reset_index()
all_starts = all_candidates['start'].values
all_candidates
# Out:
#    index  env_corr  spectral_diff    start  bout
# 0      5  0.966870       0.689503  1007991  True
# 1      3  0.977168       0.693638  1035578  True
# 2      2  0.981690       0.700902  1136363  True
# 3      1  0.981780       0.717256  1164315  True

# %%
first_to_plot = 0
plot_as_many = 20

spectrogram_kwargs = {'nperseg': n_window,
                    'noverlap': n_overlap,
                    'window': sg.gaussian(n_window, sigma),
                    'scaling': 'spectrum'}

rms_thresh = 0.;

for (i, start) in enumerate(all_candidates['start'][first_to_plot: first_to_plot 
                                                    + plot_as_many]):
    motif_start = start
    #print all_candidates[i]
    series = chan_sound.get_chunk(motif_start, motif_start + pattern_chunk.samples)
    # get the histogram
    f, t, sxx = spectrogram(series[0, :], s_f, **spectrogram_kwargs)
    # get the rms
    #print rms(st.bandpass_filter(series[:, 0], s_f))
    all_candidates.set_value(i, 'rms', st.rms(st.bandpass_filter(series[0,:], s_f)))
    plt.figure()
    plt.pcolormesh(t, f[f < f_cut], np.log(sxx[f < f_cut, :]))

all_candidates = all_candidates[all_candidates['rms'] > rms_thresh].reset_index()

# %%
store_starts = np.concatenate([all_starts[:]])
store_starts

#confirm starting points
for start in store_starts:
    motif_start = start
    #print all_candidates[i]
    series = chan_sound.get_chunk(motif_start, motif_start + pattern_chunk.samples)
    sound_chunk = st.Chunk(chan_sound, segment = [motif_start, motif_start + pattern_chunk.samples])
    # get the histogram
    f, t, sxx = spectrogram(series[0, :], s_f, **spectrogram_kwargs)
    # get the rms
    plt.figure()
    plt.pcolormesh(t, f[f < f_cut], np.log(sxx[f < f_cut, :]))

# %%
# Save in the file
log_file_name = 'search-motiff_{0:02}-rec_{1:03}.sav.log'.format(pattern, rec)
log_file_path = os.path.join(raw_file_folder, log_file_name)
# create logger with 'spam_application'
logger = logging.getLogger('aftermath_motiff_nopandas')
logger.setLevel(logging.DEBUG)
# create file handler which logs even debug messages
fh = logging.FileHandler(log_file_path)
fh.setLevel(logging.DEBUG)
# create console handler with a higher log level
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fh.setFormatter(formatter)
ch.setFormatter(formatter)
# add the handlers to the logger
logger.addHandler(fh)
logger.addHandler(ch)

def append_rows(table, new_data):
    rows = table.shape[0]
    more_rows = new_data.shape[0]
    table.resize(rows + more_rows, axis=0)
    if table.size == (rows + more_rows):
        table[rows:] = new_data
    else:
        table[rows:,:] = new_data

def unlimited_rows_data(group, table_name, data):
    try:
        table = group.create_dataset(table_name, 
                                     data=data, 
                                     dtype=data.dtype, 
                                     maxshape={None, None})
    except RuntimeError as e:
        if 'Name already exists' in str(e):
            table = group[table_name]
            append_rows(table, data)
        else:
            raise
    return table

def store_motiff(ev_file, rec, bout_starts, motiff_name):
    motiff_group = ev_file.require_group('/event_types/singing/{0}'.format(motiff_name))
    t_table = unlimited_rows_data(motiff_group, 'time_samples', bout_starts)
    r_table = unlimited_rows_data(motiff_group, 'recording', 
                                  data=np.ones_like(bout_starts)*int(rec))
    
mot_file_name = raw_file_base_name + '.sng.kwe'
mot_file_path = os.path.join(raw_file_folder, mot_file_name)    

logger.info('Storing {0} motiff starts in {1}'.format(store_starts.size, mot_file_name))
mot_file = h5py.File(mot_file_path, 'a')
store_motiff(mot_file, rec, store_starts, 'motiff_1')
mot_file.close()
logger.info('Success')
# Out:
# 2016-07-10 14:08:27,026 - aftermath_motiff_nopandas - INFO - Storing 12 motiff starts in experiment.sng.kwe
# 2016-07-10 14:08:27,060 - aftermath_motiff_nopandas - INFO - Success

# %%
def show_motiff(i):
    motif_start = start
    #print all_candidates[i]
    series = chan_sound.get_chunk(motif_start, motif_start + pattern_chunk.samples)
    # get the histogram
    f, t, sxx = spectrogram(series[0, :], s_f, **spectrogram_kwargs)
    # get the rms
    plt.figure()
    plt.pcolormesh(t, f[f < f_cut], np.log(sxx[f < f_cut, :]))
