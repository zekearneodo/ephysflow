# %% [markdown]
# # Spike detection and ffnn to predict parameters of the model
# ###### Has problems with python 3:
# - Frame selection gets confused with the axes (function get_rec_list(k_file) in /mnt/cube/earneodo/repos/ephysflow/basic_viewing/structure/kwik_functions.py)

# %%
# Definitions and functions
# %matplotlib inline
import pdb
import sys
import pandas as pd
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import matplotlib
import scipy.signal as sg
import math
import scipy as sp
import socket
import os
import wave
import struct
import h5py
from scipy.io import wavfile
from scipy.signal import spectrogram
import logging
from IPython.display import display
matplotlib.style.use('ggplot')
from ipywidgets import *
import yaml
import numpy.lib.recfunctions as rfn 
import numpy.matlib as npm
import glob
from tqdm import tqdm


# Check wich computer to decide where the things are mounted
comp_name=socket.gethostname()
print( 'Computer: ' + comp_name)

if 'txori' in comp_name or 'passaro' in comp_name or 'niao' in comp_name:
    print('known machine')
    repos_folder = os.path.abspath('/mnt/cube/earneodo/repos')
    experiment_folder = os.path.join('/mnt/cube/earneodo/bci_zf/')

sys.path.append(os.path.join(repos_folder, 'ephysflow'))
#sys.path.append(os.path.join(repos_folder, 'analysis-tools'))
sys.path.append(os.path.join(repos_folder, 'swissknife'))

from swissknife.bci.core import expstruct as et

from basic_viewing import events as evt
from basic_viewing.units import Unit
from basic_viewing.structure.core.basic_plot import plot_raster, sparse_raster
from basic_viewing.structure.core import basic_plot as bp

from basic_viewing.structure import kwik_functions as kwkf
from basic_viewing.structure.core import h5_functions as kwdf

from swissknife.h5tools import h5tools as h5
from swissknife.streamtools import streams as st
from swissknife.streamtools import spectral as sp
from swissknife.streamtools import temporal as tp

from swissknife.decoder import linear as ld
from swissknife.decoder import neural as nd

#import spike_detect_aux as aux

#from importlib import reload
logger = logging.getLogger()
handler = logging.StreamHandler()
formatter = logging.Formatter(
        '%(asctime)s %(name)-12s %(levelname)-8s %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)
logger.setLevel(logging.INFO)



print('All modules loaded')
# Out:
# Computer: niao
# known machine
# All modules loaded

# %% [markdown]
# # Functions for collecting and manipulating frames of data

# %%
def band_pass_filter(chunk, hp_b, hp_a, lp_b, lp_a):    
    chunk_hi = sg.filtfilt(hp_b, hp_a, chunk)
    chunk_filt = sg.filtfilt(lp_b, lp_a, chunk_hi)
    return chunk_filt

def filter_rms(x, filter_pars):
    return st.rms(sp.apply_butter_bandpass(x, filter_pars))

def list_sum(a_list):
    s = a_list.pop(-1)
    for new_s in a_list:
        s+=new_s
    return s

def collect_frames(starts, span, s_f, kwd_file, recs_list, chan_list):
    frames = []

    logger.info('Collecting {} frames...'.format(starts.size))
    for i_start, start in enumerate(starts):
        if i_start % 10 == 0:
            logger.info("Frame {} ...".format(i_start))
        rec = recs_list[i_start]
        one_frame = st.Chunk(st.H5Data(kwdf.get_data_set(kwd_file, rec),
                                       s_f,
                                       dtype=np.float),
                             np.array(chan_list),
                             [start, start + span])
        frames.append(one_frame)
    return frames

def spikes_array(chunk, thresholds, min_dist=10):
    #logger.info('Getting spikes from chunk with data sized {}'.format(chunk.data.shape))
    spk_lst = tp.find_spikes(chunk.data, thresholds, min_dist=min_dist)
    spk_arr = np.zeros_like(chunk.data)
    assert(len(spk_lst)==spk_arr.shape[1])
    for ch in range(len(spk_lst)):
        spk_arr[spk_lst[ch], ch] = 1
    return spk_arr

def collect_all_spk_arr(frames_list, thresholds, min_dist=10):
    return np.stack([spikes_array(fr, thresholds, min_dist=min_dist) for fr in frames_list], axis=0)

def normalize(u):
    u_max = np.repeat(np.amax(u, axis = 1, keepdims=True), u.shape[-1], axis=1)
    u_min = np.repeat(np.amin(u, axis = 1, keepdims=True), u.shape[-1], axis=1)
    u_range = u_max - u_min
    return (u - u_min)/u_range

# %% [markdown]
# # Definitions for the session and templates of the parameters

# %%
# bird and session
bird = 'z007'
sess = 'day-2016-09-10'
stim_sess = '001'

spectrogram_pars={'n_window': 512,
                 'n_overlap': 511,
                 'sigma': 30,
                 'f_cut': 10000,
                 'db_cut': 0.000065 }

filter_band = [500, 10000]

exp_par = et.get_parameters(bird, sess)
fn = et.file_names(bird, sess)
song_file_path = et.file_path(fn, 'ss', 'sng')
song_file = h5py.File(song_file_path, 'r')

pattern_names = exp_par['search_motiff']['motiff_patterns']
print(pattern_names)
# Out:
# {'motiff_1': 'motiff_1.wav'}

# %%
#pattern
m_name = 'motiff_1'
m_path = os.path.join(et.file_names(bird)['folders']['stim'], stim_sess, 
                      exp_par['search_motiff']['motiff_patterns'][m_name])

m = evt.Song(m_name, song_file)
m_chunk = st.Chunk(st.WavData2(m_path))
#plt.plot(m_chunk.data)

s_f = m_chunk.sound.s_f
filter_pars = sp.make_butter_bandpass(s_f, filter_band[0], filter_band[1])

spec_obj = sp.Spectrogram(m_chunk.data[:,0], s_f, **spectrogram_pars)
ax = spec_obj.plot()
# Out:
# 550.4
# fcut_plot 10000

# %% [markdown]
# ### Testing the pretty_spectrogram

# %%
win_s = .001
win_samples = 128*8
step_s = .001
f_cut = 15000

#n_perseg = int(s_f * win_s)
n_perseg = win_samples

s_f = 30000
#n_overlap = int(s_f * (win_s - step_s))
n_overlap = win_samples - int(s_f*step_s)


#reload(sp)
f, t, s = sp.pretty_spectrogram(m_chunk.data[:,0], s_f, fft_size=n_perseg, log=True,
                      step_size=int(s_f*step_s), db_cut=65,
                     f_min=300, f_max=7500, window=('gaussian', 80))
plt.imshow(normalize((s))[::-1], aspect='auto', cmap='inferno')
# Out:
# /home/earneodo/anaconda3/envs/tf11/lib/python3.6/site-packages/ipykernel/__main__.py:47: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ## Testing the frame chopping and visualizing

# %%
from importlib import reload

# %%
reload(kwkf)
# Out:
# <module 'basic_viewing.structure.kwik_functions' from '/mnt/cube/earneodo/repos/ephysflow/basic_viewing/structure/kwik_functions.py'>

# %%
kwd_file = et.open_kwd(bird, sess)
starts = m.get_start()
recs = m.get_rec()

m_starts = kwkf.apply_rec_offset(kwd_file, m.get_start(), m.get_rec())

i_bout = 29
#neural_chans = np.array(exp_par['channel_config']['neural'] + [exp_par['channel_config']['mic']])
neural_chans = np.array(exp_par['channel_config']['neural'])
before = 5000
after = 6000
#neural_chans = np.array([19, 23, 25, 26, 27, 29])
rec = recs[i_bout]
dset = kwdf.get_data_set(kwd_file, rec)
h5d = st.H5Data(dset, s_f, dtype=np.float, chan_list=neural_chans)
start = starts[i_bout]

lfp_frame = st.Chunk(h5d, chan_list = h5d.chan_list, segment=[start-before, start + m_chunk.samples + after])
#lfp_frame.apply_filter(sp.apply_butter_bandpass, filter_pars)

lfp_frame.plot();
lfp_frame.data.shape
#kwd_file.close()
# Out:
# (27768, 32)

# %%
# Collect all frames
#neural_chans = np.array([19, 23, 25, 26, 27, 29])
all_frames = collect_frames(starts-before, before+after+m_chunk.samples, 
                            s_f, 
                            kwd_file, recs, neural_chans)
logger.info('Will get rms')
rms_file_name = 'rms.npy'
rms_file_loc = fn['folders']['ss']
try:
    rms = np.load(os.path.join(rms_file_loc, rms_file_name))
    logger.info('Found and loaded')
except:
    logger.warning('Could not find rms npy file')
    rms = h5d.get_rms(window_size_samples=50000, n_windows=10000, rms_func=filter_rms, rms_args = (filter_pars,))
    np.save(os.path.join(rms_file_loc, rms_file_name), rms)
    

logger.info('Done')
# Out:
# 2017-06-15 18:27:30,105 root         INFO     Collecting 71 frames...
# 2017-06-15 18:27:30,106 root         INFO     Frame 0 ...
# 2017-06-15 18:27:30,395 root         INFO     Frame 10 ...
# 2017-06-15 18:27:30,571 root         INFO     Frame 20 ...
# 2017-06-15 18:27:30,802 root         INFO     Frame 30 ...
# 2017-06-15 18:27:30,963 root         INFO     Frame 40 ...
# 2017-06-15 18:27:31,116 root         INFO     Frame 50 ...
# 2017-06-15 18:27:31,208 root         INFO     Frame 60 ...
# 2017-06-15 18:27:31,369 root         INFO     Frame 70 ...
# 2017-06-15 18:27:31,376 root         INFO     Will get rms
# 2017-06-15 18:27:31,404 root         INFO     Found and loaded
# 2017-06-15 18:27:31,405 root         INFO     Done

# %% [markdown]
# # Definitions and functions to collect array of spectrograms

# %% [markdown]
# ### for all channels in one frame

# %%
# one channel spectrogram
reload(sp)
i_ch = 3
win_s = .001
win_samples = 128*16
step_s = .001
f_cut = 15000

lfp_pars = {'f_min': 0,
            'f_max': 500,
            'win_samples': 128*8,
            'step_samples': int(step_s * s_f),
            'db_cut': 90,
            's_f': s_f}
    
def array_spectrogram(x, pars, axis=-1):
    y = x.T if axis==0 else x
    t_steps, n_ch = y.shape
    
    spec_tower =[]
    for i_ch in range(n_ch):
        f, t, s = sp.pretty_spectrogram(x[:,i_ch], pars['s_f'], 
                                        fft_size=pars['win_samples'], 
                                        log=True,
                                        step_size=pars['step_samples'], db_cut=pars['db_cut'],
                                        f_min=pars['f_min'], f_max=pars['f_max'], 
                                        window=('gaussian', pars['win_samples']//4))
        
        spec_tower.append(s)
    return np.stack(spec_tower, axis=0)
    
frame_spec = array_spectrogram(all_frames[0].data, pars=lfp_pars)
#plt.imshow(((s))[::-1], aspect='auto', cmap='inferno')

frame_spec.shape
# Out:
# (32, 17, 892)

# %% [markdown]
# ### For all frames in a stack (list)

# %%
def collect_all_spectra(all_frames, lfp_pars):
    all_spectra= []
    for i, fr in tqdm(enumerate(all_frames)):
        one_s = array_spectrogram(fr.data, lfp_pars, axis=-1)
        all_spectra.append(one_s)

    all_spectra_array = np.stack(all_spectra, axis=0)
    return all_spectra_array

all_spec_array = collect_all_spectra(all_frames, lfp_pars)
logger.info('{}'.format(all_spec_array.shape))
# Out:
# 44it [00:38,  1.16it/s]

# %%
[n_frames, n_chans, n_bands, n_steps] = all_spec_array.shape
all_spectra_sv = all_spec_array.reshape([n_frames, -1, n_steps])
all_spectra_sv.shape
#plt.imshow(all_spectra_sv)

# %%
# logarithmic frequency bands

# %%
# view LFP BAND 'RASTERS'
ch = 30
for band in range(15):
    plt.figure()
    plt.imshow(all_spec_array[:,ch, band,:], aspect='auto')

# %%
# view LFP BAND 'RASTERS' from the squeezed all_spectra_sv
ch = 30
for band in range(15):
    plt.figure()
    plt.imshow(all_spectra_sv[:,ch*n_bands + band,:], aspect='auto')

# %%
lfp_pars

# %% [markdown]
# # Making freature vectors (arrays)

# %% [markdown]
# ### Lfp feature vectors

# %%
def feature_vector_from_lfp(starts, recs, len_samples, channels, kwd_file, lfp_pars,
                            bin_size=10, s_f=30000, history_bins=1, no_silent=True):
    logger.info('Starts shape {}'.format(starts.shape))
    bin_size_samples = int(bin_size * s_f / 1000.)
    len_bin = int(len_samples / bin_size_samples)
    len_ms = int(len_bin * bin_size)
    history_samples = history_bins * bin_size_samples
    window_samples = lfp_pars['win_samples']
    span_ms = len_ms + bin_size * history_bins
    span_samples = int(span_ms * s_f / 1000.)

    logger.info('span_ms = {}'.format(span_ms))
    logger.info('bin_ms = {}'.format(bin_size))
    
    all_frames = collect_frames(starts - history_samples - window_samples,
                                span_samples + window_samples,
                                s_f,
                                kwd_file,
                                recs,
                                channels)
    
    logger.info('Frame shape {}'.format(all_frames[0].data.shape))
    # collect all the spectral bands for all the frames in all the channels
    logger.info('Collecting the spectral features for the {} frames'.format(starts.size))
    
    all_spec_array = collect_all_spectra(all_frames, lfp_pars)
    logger.info('all_spec_array shape {}'.format(all_spec_array.shape))

    # reshape it into a [n_frame, n_chans*n_bands, n_steps] array
    [n_frames, n_chans, n_bands, n_steps] = all_spec_array.shape
    
    all_spectra_fv = all_spec_array.reshape([n_frames, -1, n_steps])
    
    logger.info('all_spectra_fv shape = {}'.format(all_spectra_fv.shape))
    
    all_spectra_sv = np.stack([bp.col_binned(all_spectra_fv[t,:,:span_ms], bin_size) 
                               for t in range(n_frames)], axis=2)
    
    return all_spectra_sv/np.max(all_spectra_sv), all_spectra_fv

# %% [markdown]
# ### Supra-threshold events feature vectors

# %%
trials_train = np.arange(65)
trials_test = np.arange(65,71)

def find_silent(sup_vec):
    silent_list = np.array([any(~(sup_vec[i,:,:].any(axis=0))) for i in range(sup_vec.shape[0])])
    return silent_list

def support_vector_from_raw(starts, recs, len_samples, channels, thresholds, kwd_file,
                            bin_size=10, s_f=30000, history_bins=1, no_silent=True):
    print(starts.shape)
    bin_size_samples = int(bin_size * s_f / 1000.)
    len_bin = int(len_samples / bin_size_samples)
    len_ms = int(len_bin * bin_size)
    history_samples = history_bins * bin_size_samples
    span_ms = len_ms + bin_size * history_bins
    span_samples = int(span_ms * s_f / 1000.)

    logger.info('span_ms = {}'.format(span_ms))
    # logger.info('{} units'.format(len(all_units)))

    all_frames = collect_frames(starts - history_samples,
                                span_samples,
                                s_f,
                                kwd_file,
                                recs,
                                channels)
    
    logger.info('Frame shape {}'.format(all_frames[0].data.shape))
    [fr.apply_filter(sp.apply_butter_bandpass, filter_pars) for fr in all_frames]
    all_spk_arr = collect_all_spk_arr(all_frames, thresholds)
    
    logger.info('all_spk_arr shape {}'.format(all_spk_arr.shape))
    rst_sv = np.stack([bp.col_binned(all_spk_arr[t,:,:].T, bin_size_samples) for t in range(all_spk_arr.shape[0])], 
                      axis=2)
    
    if no_silent:
        good_chans = ~find_silent(rst_sv)
    else:
        good_chans = channels

    return rst_sv[good_chans, :, :]


spike_thresh = 3.5
thresh = rms*spike_thresh
sv=support_vector_from_raw(starts, recs, m_chunk.samples, neural_chans, thresh, kwd_file)
print(sv.shape)

# %%
lsv, _= feature_vector_from_lfp(starts, recs, m_chunk.samples, neural_chans, kwd_file, lfp_pars)
print(lsv.shape)

# %%
print(sv.shape)
print(lsv.shape)

# %% [markdown]
# # APPLY ALL THAT TO PREDICT THE PARAMETERS OF THE MODEL

# %%
## Get the parameters

# %%
# INTO THE WILD FITTING NOW
def transform_env(x):
    x[x<0] = 0
    return x

def transform_alpha(x):
    x[x<0.15] = 0
    x[x>=.15] = .3
    return x

def transform_beta(x):
    x[x<0] = 0
    return x

def mu_transform_beta(x):
    x[x<0] = 0
    return syn.np_mulog_inv(x, 256)

# %%
# Try a fit
fns = et.file_names(bird, '002')
all_aligned = np.load(os.path.join(fns['folders']['stim'], 'par_stream_aligned.npy'))
alpha = all_aligned[:, 0]
beta = all_aligned[:, 1]
env = all_aligned[:, 2]

# %%
plt.plot(alpha)

# %% [markdown]
# ## Make the feature vectors

# %% [markdown]
# #### spikes

# %%
import spike_detect_aux as aux
# Out:
# 2017-06-14 10:06:36,124 spike_detect_aux INFO     Computer: niao
# 2017-06-14 10:06:36,124 spike_detect_aux INFO     Computer: niao

# %%
reload(aux)
from swissknife.bci import synthetic as syn

par_stream = syn.np_mulog(beta)
from swissknife.decoder import linear as ld
trials_train = np.arange(71)

bin_size = 4
history_bins = 30

chans = np.arange(thresh.size)

bin_size_samples = int(bin_size*s_f/1000.)
len_samples = par_stream.shape[0]
model_pars = bp.col_binned(np.array([par_stream]), bin_size_samples)/bin_size_samples

all_s_v = []
for thresh_factor in [5.5]:
    thresh = rms*thresh_factor
    s_v_new = support_vector_from_raw(starts, recs, len_samples, chans, thresh, kwd_file,
                            bin_size=bin_size, s_f=s_f, history_bins=history_bins+1, no_silent=True)
    all_s_v.append(s_v_new)

s_v = np.concatenate(all_s_v, axis=0)
target = np.tile(model_pars, starts.size).reshape(starts.size, -1)
logger.info('sv shape {0}, target shape {1}'.format(s_v.shape, target.shape))
# Out:
# 2017-06-14 14:05:43,523 spike_detect_aux INFO     Computer: niao
# 2017-06-14 14:05:43,523 spike_detect_aux INFO     Computer: niao
# 2017-06-14 14:05:43,525 root         INFO     span_ms = 772
# 2017-06-14 14:05:43,525 root         INFO     span_ms = 772
# 2017-06-14 14:05:43,526 root         INFO     Collecting 71 frames...
# 2017-06-14 14:05:43,526 root         INFO     Collecting 71 frames...
# 2017-06-14 14:05:43,527 root         INFO     Frame 0 ...
# 2017-06-14 14:05:43,527 root         INFO     Frame 0 ...
# 2017-06-14 14:05:43,604 root         INFO     Frame 10 ...
# 2017-06-14 14:05:43,604 root         INFO     Frame 10 ...
# 2017-06-14 14:05:43,664 root         INFO     Frame 20 ...
# 2017-06-14 14:05:43,664 root         INFO     Frame 20 ...
# 2017-06-14 14:05:43,714 root         INFO     Frame 30 ...
# 2017-06-14 14:05:43,714 root         INFO     Frame 30 ...
# (71,)
# 2017-06-14 14:05:43,766 root         INFO     Frame 40 ...
# 2017-06-14 14:05:43,766 root         INFO     Frame 40 ...
# 2017-06-14 14:05:43,814 root         INFO     Frame 50 ...
# 2017-06-14 14:05:43,814 root         INFO     Frame 50 ...
# 2017-06-14 14:05:43,890 root         INFO     Frame 60 ...
# 2017-06-14 14:05:43,890 root         INFO     Frame 60 ...
# 2017-06-14 14:05:43,940 root         INFO     Frame 70 ...
# 2017-06-14 14:05:43,940 root         INFO     Frame 70 ...
# 2017-06-14 14:05:43,946 root         INFO     Frame shape (23160, 32)
# 2017-06-14 14:05:43,946 root         INFO     Frame shape (23160, 32)
# 2017-06-14 14:05:48,961 root         INFO     all_spk_arr shape (71, 23160, 32)
# 2017-06-14 14:05:48,961 root         INFO     all_spk_arr shape (71, 23160, 32)
# 2017-06-14 14:05:49,234 root         INFO     sv shape (28, 193, 71), target shape (71, 163)
# 2017-06-14 14:05:49,234 root         INFO     sv shape (28, 193, 71), target shape (71, 163)

# %%
s_v.shape
# Out:
# (28, 193, 71)

# %% [markdown]
# #### Lfp

# %%
lfp_sv, all_spectra_fv =feature_vector_from_lfp(starts, recs, len_samples, neural_chans, kwd_file, lfp_pars, 
                           bin_size=bin_size, history_bins=history_bins+1)
print(lfp_sv.shape)
# Out:
# 2017-06-14 14:05:49,345 root         INFO     Starts shape (71,)
# 2017-06-14 14:05:49,345 root         INFO     Starts shape (71,)
# 2017-06-14 14:05:49,347 root         INFO     span_ms = 772
# 2017-06-14 14:05:49,347 root         INFO     span_ms = 772
# 2017-06-14 14:05:49,347 root         INFO     bin_ms = 4
# 2017-06-14 14:05:49,347 root         INFO     bin_ms = 4
# 2017-06-14 14:05:49,348 root         INFO     Collecting 71 frames...
# 2017-06-14 14:05:49,348 root         INFO     Collecting 71 frames...
# 2017-06-14 14:05:49,349 root         INFO     Frame 0 ...
# 2017-06-14 14:05:49,349 root         INFO     Frame 0 ...
# 2017-06-14 14:05:49,418 root         INFO     Frame 10 ...
# 2017-06-14 14:05:49,418 root         INFO     Frame 10 ...
# 2017-06-14 14:05:49,473 root         INFO     Frame 20 ...
# 2017-06-14 14:05:49,473 root         INFO     Frame 20 ...
# 2017-06-14 14:05:49,530 root         INFO     Frame 30 ...
# 2017-06-14 14:05:49,530 root         INFO     Frame 30 ...
# 2017-06-14 14:05:49,596 root         INFO     Frame 40 ...
# 2017-06-14 14:05:49,596 root         INFO     Frame 40 ...
# 2017-06-14 14:05:49,695 root         INFO     Frame 50 ...
# 2017-06-14 14:05:49,695 root         INFO     Frame 50 ...
# 2017-06-14 14:05:49,776 root         INFO     Frame 60 ...
# 2017-06-14 14:05:49,776 root         INFO     Frame 60 ...
# 2017-06-14 14:05:49,914 root         INFO     Frame 70 ...
# 2017-06-14 14:05:49,914 root         INFO     Frame 70 ...
# 2017-06-14 14:05:49,919 root         INFO     Frame shape (24184, 32)
# 2017-06-14 14:05:49,919 root         INFO     Frame shape (24184, 32)
# 2017-06-14 14:05:49,921 root         INFO     Collecting the spectral features for the 71 frames
# 2017-06-14 14:05:49,921 root         INFO     Collecting the spectral features for the 71 frames
# 71it [00:51,  1.36it/s]
# 2017-06-14 14:06:42,130 root         INFO     all_spec_array shape (71, 32, 17, 773)
# 2017-06-14 14:06:42,130 root         INFO     all_spec_array shape (71, 32, 17, 773)
# 2017-06-14 14:06:42,131 root         INFO     all_spectra_fv shape = (71, 544, 773)
# 2017-06-14 14:06:42,131 root         INFO     all_spectra_fv shape = (71, 544, 773)
# (544, 193, 71)

# %%
print(s_v.shape)
print(lfp_sv.shape)
print(target.shape)
# Out:
# (28, 193, 71)
# (544, 193, 71)
# (71, 163)

# %% [markdown]
# #### Merge spikes and lfp

# %%
from swissknife.decoder import neural as nd
reload(nd)

all_sv = np.concatenate([s_v, lfp_sv], axis=0)
logger.info('Shape of lfp + spikes feature vector: {}'.format(all_sv.shape))
X_train, Y_train, X_test, Y_test = nd.sup_to_keras(all_sv, target, history_bins, n_test=10)
# Out:
# 2017-06-14 14:06:46,861 root         INFO     Shape of lfp + spikes feature vector: (572, 193, 71)
# 2017-06-14 14:06:46,861 root         INFO     Shape of lfp + spikes feature vector: (572, 193, 71)
# 2017-06-14 14:06:46,862 decoder.datashape WARNING  Size mismatch between target and support vector
# 2017-06-14 14:06:46,862 decoder.datashape WARNING  Size mismatch between target and support vector
# 2017-06-14 14:06:54,080 decoder.neural INFO     Train vector sizes (9943, 17160) and (9943,)
# 2017-06-14 14:06:54,080 decoder.neural INFO     Train vector sizes (9943, 17160) and (9943,)
# 2017-06-14 14:06:54,081 decoder.neural INFO     Test vector sizes (1630, 17160) and (1630,)
# 2017-06-14 14:06:54,081 decoder.neural INFO     Test vector sizes (1630, 17160) and (1630,)

# %% [markdown]
# ## Make the networks and fit the parameters

# %%
from keras.layers.core import Dense, Activation
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint

n_feat = X_train.shape[-1]
n_target = 1
#n_target = Y_train.shape[-1]
num_ep = 120

model = Sequential()
model.add(Dense(n_feat//2, input_dim=n_feat, kernel_initializer='uniform', activation='relu'))
model.add(Dense(n_feat//4, input_dim=n_feat, kernel_initializer='uniform', activation='relu'))
model.add(Dense(n_feat//8, input_dim=n_feat, kernel_initializer='uniform', activation='relu'))
model.add(Dense(n_feat//16, input_dim=n_feat, kernel_initializer='uniform', activation='relu'))
model.add(Dense(n_target, kernel_initializer='normal'))
#model.compile(loss='mean_squared_error', optimizer='adam')
model.compile(loss='mean_absolute_error', optimizer='rmsprop')


model_name = 'ff_lfp_warptemp_bs{0:02d}_hs{1:02d}_te{2:03d}.h5'.format(bin_size, history_bins, num_ep)
model_path = os.path.join(fn['folders']['ss'], 'model_' + model_name)
weights_path = os.path.join(fn['folders']['ss'], 'weights_' + model_name)
callbacks = [EarlyStopping(monitor='val_loss', patience=4, verbose=1),
             ModelCheckpoint(filepath=model_path, monitor='val_loss', save_best_only=True, verbose=1)
            ]

model.fit(X_train, Y_train, nb_epoch=num_ep, batch_size=5, verbose=1, validation_split=0.1, callbacks=callbacks)
score = model.evaluate(X_test, Y_test, batch_size=5)
# Out:
# /home/earneodo/anaconda3/envs/tf11/lib/python3.6/site-packages/keras/models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 8948 samples, validate on 995 samples
# Epoch 1/120
# 8945/8948 [============================>.] - ETA: 1s - loss: 21.5304Epoch 00000: val_loss improved from inf to 0.14550, saving model to /mnt/cube/earneodo/bci_zf/ss_data/z007/day-2016-09-10/model_ff_lfp_warptemp_bs04_hs30_te120.h5
# 8948/8948 [==============================] - 3626s - loss: 21.5232 - val_loss: 0.1455
# Epoch 2/120
# 8945/8948 [============================>.] - ETA: 1s - loss: 0.1447Epoch 00001: val_loss did not improve
# 8948/8948 [==============================] - 3643s - loss: 0.1447 - val_loss: 0.2862
# Epoch 3/120
# 8945/8948 [============================>.] - ETA: 1s - loss: 0.1054Epoch 00002: val_loss improved from 0.14550 to 0.08826, saving model to /mnt/cube/earneodo/bci_zf/ss_data/z007/day-2016-09-10/model_ff_lfp_warptemp_bs04_hs30_te120.h5
# 8948/8948 [==============================] - 3523s - loss: 0.1054 - val_loss: 0.0883
# Epoch 4/120
# 8945/8948 [============================>.] - ETA: 1s - loss: 0.0931Epoch 00003: val_loss improved from 0.08826 to 0.08743, saving model to /mnt/cube/earneodo/bci_zf/ss_data/z007/day-2016-09-10/model_ff_lfp_warptemp_bs04_hs30_te120.h5
# 8948/8948 [==============================] - 3491s - loss: 0.0931 - val_loss: 0.0874
# Epoch 5/120
# 8945/8948 [============================>.] - ETA: 1s - loss: 0.0860Epoch 00004: val_loss did not improve
# 8948/8948 [==============================] - 3564s - loss: 0.0860 - val_loss: 0.1720
# Epoch 6/120
# 7425/8948 [=======================>......] - ETA: 596s - loss: 0.0825

# %% [markdown]
# ## Visualize predictions

# %%
#4ms 25 bins history
pred = model.predict(X_test, batch_size=5)
plt.plot((np.reshape(pred.flatten(), (10, -1)).T));
plt.plot((target.T), 'k');

# %%
#4ms 25 bins history
pred = model.predict(X_test, batch_size=15)
plt.plot((np.reshape(pred.flatten(), (10, -1)).T));
plt.plot((target.T), 'k');

# %%
#3ms 25 bins history
pred = model.predict(X_test, batch_size=15)
plt.plot((np.reshape(pred.flatten(), (10, -1)).T));
plt.plot((target.T), 'k');

# %%
#2ms 30 bins history
pred = model.predict(X_test, batch_size=15)
plt.plot((np.reshape(pred.flatten(), (10, -1)).T));
plt.plot((target.T), 'k');

# %%
reload(aux)
from bci import synthetic as syn

par_stream = syn.np_mulog(beta)
from decoder import linear as ld
trials_train = np.arange(65)
trials_test = np.arange(65,71)
b_s = 11
h_b = 27
thresh_factor = 5.5
thresh = rms*thresh_factor
chans = np.arange(thresh.size)
fitted_kernel, fitted_chans = aux.linear_fit(chans, thresh, kwd_file, starts[trials_train], recs[trials_train], par_stream, 
                       bin_size=b_s, history_bins=h_b)
#fitted_kernel.flatten()
par_pred = aux.linear_predict(chans[fitted_chans], thresh[fitted_chans], kwd_file, starts[trials_test], recs[trials_test], par_stream.size, fitted_kernel, 
                   bin_size=b_s, 
                   history_bins=h_b, 
                   s_f=30000,
                   no_silent=False)

plt.plot(syn.np_mulog_inv(aux.transform_beta(par_pred)).T);
plt.plot(syn.np_mulog_inv(bp.col_binned(par_stream.reshape(1, -1), b_s*30).T/(b_s*30)), 'k');
# Out:
# 2017-02-06 07:48:29,152 spike_detect_aux INFO     Computer: passaro
# 2017-02-06 07:48:29,157 spike_detect_aux INFO     Fitting a kernel
# 2017-02-06 07:48:29,159 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2017-02-06 07:48:29,161 spike_detect_aux INFO     Collecting 65 frames...
# 2017-02-06 07:48:29,163 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:48:29,253 spike_detect_aux INFO     Frame 10 ...
# 2017-02-06 07:48:29,324 spike_detect_aux INFO     Frame 20 ...
# 2017-02-06 07:48:29,385 spike_detect_aux INFO     Frame 30 ...
# 2017-02-06 07:48:29,437 spike_detect_aux INFO     Frame 40 ...
# 2017-02-06 07:48:29,486 spike_detect_aux INFO     Frame 50 ...
# 2017-02-06 07:48:29,534 spike_detect_aux INFO     Frame 60 ...
# 2017-02-06 07:48:34,463 spike_detect_aux INFO     sv shape (30, 87, 65), target shape (65, 60)
# 2017-02-06 07:48:34,581 spike_detect_aux INFO     k shape (841,)
# 2017-02-06 07:48:34,582 spike_detect_aux INFO     Convolving a kernel
# 2017-02-06 07:48:34,583 spike_detect_aux INFO     Channels are 30
# 2017-02-06 07:48:34,583 spike_detect_aux INFO     Creating support vector 30 chans, 6 trials
# 2017-02-06 07:48:34,584 spike_detect_aux INFO     Collecting 6 frames...
# 2017-02-06 07:48:34,585 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:48:35,009 spike_detect_aux INFO     kernel shape (841,), sv_shape (30, 87, 6), len_samples 19546

# %%
nice_alpha = {'thresh_f': thresh_factor, 'bs': b_s, 'hb': h_b, 'streams': aux.transform_alpha(par_pred)}

# %%
plt.plot(beta)

# %%
plt.plot(nice_alpha['streams'].T);

# %%
reload(bp)
#plt.plot(beta)
b_s = 10

plt.plot(bp.col_binned(beta.reshape(1, -1), 30));

# %%
plt.plot(syn.np_mulog(beta))

# %%
nice_beta = {'thresh_f': thresh_factor, 'bs': b_s, 'hb': h_b, 'streams': aux.transform_alpha(par_pred)}

# %%
reload(aux)
fit_result = aux.test_fit(chans, thresh, kwd_file, starts, recs, trials_train, trials_test, par_stream,
            bin_size=b_s,
            history_bins=h_b)
# Out:
# 2017-02-06 07:49:28,977 spike_detect_aux INFO     Computer: passaro
# 2017-02-06 07:49:28,979 spike_detect_aux INFO     Fitting a kernel
# 2017-02-06 07:49:28,981 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2017-02-06 07:49:28,983 spike_detect_aux INFO     Collecting 65 frames...
# 2017-02-06 07:49:28,984 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:49:29,067 spike_detect_aux INFO     Frame 10 ...
# 2017-02-06 07:49:29,135 spike_detect_aux INFO     Frame 20 ...
# 2017-02-06 07:49:29,212 spike_detect_aux INFO     Frame 30 ...
# 2017-02-06 07:49:29,286 spike_detect_aux INFO     Frame 40 ...
# 2017-02-06 07:49:29,350 spike_detect_aux INFO     Frame 50 ...
# 2017-02-06 07:49:29,405 spike_detect_aux INFO     Frame 60 ...
# 2017-02-06 07:49:34,074 spike_detect_aux INFO     sv shape (30, 93, 65), target shape (65, 66)
# 2017-02-06 07:49:34,206 spike_detect_aux INFO     k shape (841,)
# 2017-02-06 07:49:34,207 spike_detect_aux INFO     Convolving a kernel
# 2017-02-06 07:49:34,208 spike_detect_aux INFO     Channels are 30
# 2017-02-06 07:49:34,208 spike_detect_aux INFO     Creating support vector 30 chans, 6 trials
# 2017-02-06 07:49:34,209 spike_detect_aux INFO     Collecting 6 frames...
# 2017-02-06 07:49:34,210 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:49:34,607 spike_detect_aux INFO     kernel shape (841,), sv_shape (30, 93, 6), len_samples 19546

# %%
plt.plot(fit_result[1].T);
plt.plot(fit_result[3].T, 'k')
# Out:
# [<matplotlib.lines.Line2D at 0x7f0877737e10>,
#  <matplotlib.lines.Line2D at 0x7f087793f4d0>,
#  <matplotlib.lines.Line2D at 0x7f087793f5d0>,
#  <matplotlib.lines.Line2D at 0x7f087793f6d0>,
#  <matplotlib.lines.Line2D at 0x7f087793f810>,
#  <matplotlib.lines.Line2D at 0x7f087793f950>]

# %%
reload(aux)
b_s = 11
h_b = 29
thresh_factor = 5.5
thresh = rms*thresh_factor
all_result = aux.altogether_test(alpha, syn.np_mulog(beta), env, 
                                 chans, thresh, kwd_file, starts, recs, trials_train, trials_test,
                                 bin_size=b_s,
                                 history_bins=h_b)

for i_par, _ in enumerate(all_result[0]):
    plt.figure()
    plt.plot(all_result[1][i_par].T);
    plt.plot(all_result[3][i_par].T, 'k.')
# Out:
# 2017-02-06 07:50:05,814 spike_detect_aux INFO     Computer: passaro
# 2017-02-06 07:50:05,818 spike_detect_aux INFO     Testing for all pars with bin_size=11, history_size=29:
# 2017-02-06 07:50:05,819 spike_detect_aux INFO     Testing fit for a parameter
# 2017-02-06 07:50:05,821 spike_detect_aux INFO     Fitting a kernel
# 2017-02-06 07:50:05,823 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2017-02-06 07:50:05,824 spike_detect_aux INFO     Collecting 65 frames...
# 2017-02-06 07:50:05,826 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:05,913 spike_detect_aux INFO     Frame 10 ...
# 2017-02-06 07:50:05,981 spike_detect_aux INFO     Frame 20 ...
# 2017-02-06 07:50:06,042 spike_detect_aux INFO     Frame 30 ...
# 2017-02-06 07:50:06,113 spike_detect_aux INFO     Frame 40 ...
# 2017-02-06 07:50:06,164 spike_detect_aux INFO     Frame 50 ...
# 2017-02-06 07:50:06,254 spike_detect_aux INFO     Frame 60 ...
# 2017-02-06 07:50:11,321 spike_detect_aux INFO     sv shape (30, 89, 65), target shape (65, 60)
# 2017-02-06 07:50:11,446 spike_detect_aux INFO     k shape (901,)
# 2017-02-06 07:50:11,447 spike_detect_aux INFO     Convolving a kernel
# 2017-02-06 07:50:11,448 spike_detect_aux INFO     Channels are 30
# 2017-02-06 07:50:11,449 spike_detect_aux INFO     Creating support vector 30 chans, 6 trials
# 2017-02-06 07:50:11,449 spike_detect_aux INFO     Collecting 6 frames...
# 2017-02-06 07:50:11,450 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:11,895 spike_detect_aux INFO     kernel shape (901,), sv_shape (30, 89, 6), len_samples 19546
# 2017-02-06 07:50:11,905 spike_detect_aux INFO     Testing fit for a parameter
# 2017-02-06 07:50:11,907 spike_detect_aux INFO     Fitting a kernel
# 2017-02-06 07:50:11,912 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2017-02-06 07:50:11,913 spike_detect_aux INFO     Collecting 65 frames...
# 2017-02-06 07:50:11,915 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:11,967 spike_detect_aux INFO     Frame 10 ...
# 2017-02-06 07:50:12,011 spike_detect_aux INFO     Frame 20 ...
# 2017-02-06 07:50:12,053 spike_detect_aux INFO     Frame 30 ...
# 2017-02-06 07:50:12,095 spike_detect_aux INFO     Frame 40 ...
# 2017-02-06 07:50:12,138 spike_detect_aux INFO     Frame 50 ...
# 2017-02-06 07:50:12,181 spike_detect_aux INFO     Frame 60 ...
# 2017-02-06 07:50:17,153 spike_detect_aux INFO     sv shape (30, 89, 65), target shape (65, 60)
# 2017-02-06 07:50:17,273 spike_detect_aux INFO     k shape (901,)
# 2017-02-06 07:50:17,274 spike_detect_aux INFO     Convolving a kernel
# 2017-02-06 07:50:17,274 spike_detect_aux INFO     Channels are 30
# 2017-02-06 07:50:17,275 spike_detect_aux INFO     Creating support vector 30 chans, 6 trials
# 2017-02-06 07:50:17,276 spike_detect_aux INFO     Collecting 6 frames...
# 2017-02-06 07:50:17,277 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:17,694 spike_detect_aux INFO     kernel shape (901,), sv_shape (30, 89, 6), len_samples 19546
# 2017-02-06 07:50:17,697 spike_detect_aux INFO     Testing fit for a parameter
# 2017-02-06 07:50:17,698 spike_detect_aux INFO     Fitting a kernel
# 2017-02-06 07:50:17,699 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2017-02-06 07:50:17,700 spike_detect_aux INFO     Collecting 65 frames...
# 2017-02-06 07:50:17,701 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:17,749 spike_detect_aux INFO     Frame 10 ...
# 2017-02-06 07:50:17,795 spike_detect_aux INFO     Frame 20 ...
# 2017-02-06 07:50:17,838 spike_detect_aux INFO     Frame 30 ...
# 2017-02-06 07:50:17,880 spike_detect_aux INFO     Frame 40 ...
# 2017-02-06 07:50:17,924 spike_detect_aux INFO     Frame 50 ...
# 2017-02-06 07:50:17,966 spike_detect_aux INFO     Frame 60 ...
# 2017-02-06 07:50:22,970 spike_detect_aux INFO     sv shape (30, 89, 65), target shape (65, 60)
# 2017-02-06 07:50:23,081 spike_detect_aux INFO     k shape (901,)
# 2017-02-06 07:50:23,082 spike_detect_aux INFO     Convolving a kernel
# 2017-02-06 07:50:23,083 spike_detect_aux INFO     Channels are 30
# 2017-02-06 07:50:23,083 spike_detect_aux INFO     Creating support vector 30 chans, 6 trials
# 2017-02-06 07:50:23,084 spike_detect_aux INFO     Collecting 6 frames...
# 2017-02-06 07:50:23,085 spike_detect_aux INFO     Frame 0 ...
# 2017-02-06 07:50:23,505 spike_detect_aux INFO     kernel shape (901,), sv_shape (30, 89, 6), len_samples 19546

# %%
def resample_no_interp(x, s_f, new_s_f, axis=0):
    assert(new_s_f>=s_f)
    n_repeats = np.int(np.ceil(new_s_f/s_f))
    return np.repeat(x, n_repeats, axis=axis)

#now try to synthesise for this test
def latent_to_stream(onof, beta, alpha):
    onof[onof>.3] = .3
    onof[onof<0] = 0
    alpha[alpha<0]=0
    return np.vstack([0.15 - onof, -beta, alpha]).T

n_test = 5
fitted_streams = all_result[3][:,n_test,:]


abe_streams = latent_to_stream(fitted_streams[0, :], 
                               syn.np_mulog_inv(fitted_streams[1, :]), 
                               fitted_streams[2, :])

abe_streams_rs = resample_no_interp(abe_streams, 1000./b_s, 44100)
plt.plot(abe_streams_rs[:,1])

# %%
from scipy.signal import savgol_filter
abe_streams_rs[:,1] = savgol_filter(abe_streams_rs[:,1], 441, 3)
abe_streams_rs[abe_streams_rs[:,1] > 0, 1] = 0
# smooth_some
plt.plot(abe_streams_rs[:,1])

# %%
abe_streams_rs[:,2] = savgol_filter(abe_streams_rs[:,2], 661, 3)
abe_streams_rs[abe_streams_rs[:,2] < 0, 2] = 0
# smooth_some
plt.plot(abe_streams_rs[:,2])

# %%
from dynamo import finch as zf
s_s = zf.make_song(abe_streams_rs)
plt.plot(s_s[:,0])

# %%
plt.plot(s_s[:, 0])
def wavify(x):
    return (x/np.ptp(x)*30000).astype(np.int16)

plt.plot(wavify(s_s[:, 0]))

wav_fn = os.path.join(et.file_names(bird, '002')['folders']['stim'], 'synth_thresh2.wav')
wavfile.write(wav_fn, 44100, wavify(s_s[:, 0]))

# %%
plt.plot(s_s[1500:1700, :])
# Out:
# [<matplotlib.lines.Line2D at 0x7f086e7b26d0>,
#  <matplotlib.lines.Line2D at 0x7f086e7b28d0>]

# %%
def plot_spectrogram(x, before_ms, after_ms, s_f, n_window = 192, n_overlap = None, sigma=None, ax=None, **kwargs):
    
    if n_overlap is None:
        n_overlap = n_window/2
    if sigma is None:
        sigma = 1./1000.*s_f
    
    # Make the spectrogram
    f, t, Sxx = spectrogram(x, s_f, nperseg = n_window, noverlap=n_overlap, window = sg.gaussian(n_window, sigma), 
                            scaling='spectrum')
    
    Sxx[[Sxx<np.max((Sxx)*0.000065)]]=1

    span_before = np.zeros((Sxx.shape[0], np.int(before_ms/1000. * s_f)))
    span_after = np.zeros((Sxx.shape[0], np.int(after_ms/1000. * s_f) + x.size - Sxx.shape[1]))
    span_before[:] = np.nan
    span_after[:] = np.nan
    #Sxx = np.hstack((span_before, (Sxx), span_after))
    
    if ax is None:
        spec_fig = plt.figure()
        ax = spec_fig.add_axes([0, 0, 1, 1])
        
    ax.pcolormesh(((t-0.5*n_window/s_f)*1000.), f, np.log(Sxx), rasterized=True)
    ax.set_xlim(-before_ms, after_ms + int(x.size/s_f * 1000.))
    ax.set_ylim(0,10000)
    #ax.plot((span_before.shape[1], span_before.shape[1]), (np.min(f), np.max(f)), 'k--')
    
    return Sxx, ax

spectr_bos, ax = plot_spectrogram(s_s[:, 0], 
                                   0, 0, 44100,
                                   n_window = 512, n_overlap=512-1, scaling='spectrum')
# Out:
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:2782: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))

# %%
for i_par, _ in enumerate(all_result[0]):
    plt.figure()
    plt.plot(all_result[1][i_par].T);
    plt.plot(all_result[3][i_par].T, 'k')

# %%
#plt.plot(all_result[1][0].T);
plt.plot(all_result[1][0].T);
plt.plot(all_result[3][0].T, 'k')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd665c78f10>,
#  <matplotlib.lines.Line2D at 0x7fd665b3aa10>,
#  <matplotlib.lines.Line2D at 0x7fd665b3ab10>,
#  <matplotlib.lines.Line2D at 0x7fd665b3ac10>,
#  <matplotlib.lines.Line2D at 0x7fd665b3ad50>,
#  <matplotlib.lines.Line2D at 0x7fd665b3ae90>]

# %%
reload(aux)
env_pred = aux.linear_predict(chans[fitted_chans], thresh[fitted_chans], kwd_file, starts[trials_test], recs[trials_test], env.size, 
                              fitted_kernel, 
                   bin_size=b_s, 
                   history_bins=h_b, 
                   s_f=30000,
                   no_silent=False)
# Out:
# 2016-12-13 10:39:17,631 spike_detect_aux INFO     Computer: passaro
# 2016-12-13 10:39:17,633 spike_detect_aux INFO     k shape (465,)
# 2016-12-13 10:39:17,635 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 10:39:17,636 spike_detect_aux INFO     Channels are 29
# 2016-12-13 10:39:17,638 spike_detect_aux INFO     Creating support vector 29 chans, 6 trials
# 2016-12-13 10:39:17,639 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 10:39:17,641 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 10:39:18,073 spike_detect_aux INFO     kernel shape (465,), sv_shape (29, 81, 6), len_samples 19503

# %%
plt.plot(env_pred[1])

# %%
plt.plot(env_pred.T);
plt.plot(bp.col_binned(env.reshape(1, -1), b_s*30).T/(b_s*30), 'k');

# %%
all_result = aux.altogether_test(alpha, beta, env, 
                                 chans, thresh, kwd_file, starts, recs, trials_train, trials_test,
                                 bin_size=b_s,
                                 history_bins=h_b)
# Out:
# array([[ 0.11122297,  0.10719738,  0.10260112, ...,  2.7971164 ,
#          2.64351626,  1.48117981]])

# %%
s_f
# Out:
# 30000

# %%
bins = [5, 6, 7, 8, 9, 10, 12, 15]
histories = [5, 6, 7, 8, 9, 10, 12, 15, 17, 20, 22, 25, 27]
tests_sweep = []
for bs in bins:
    bs_sweep = []
    for hs in histories:
        logger.info('Testing with bs={0}, hs={1}:'.format(bs, hs))
        ev_tst = aux.altogether_test(alpha, syn.np_mulog(beta, 256), env, 
                                 chans, thresh, kwd_file, starts, recs, trials_train, trials_test,
                             bin_size=bs, 
                             history_bins=hs, 
                             s_f=s_f, 
                             nl_alpha = aux.transform_alpha, 
                             nl_beta = aux.transform_beta, 
                             nl_env = aux.transform_env
                            )
        bs_sweep.append(ev_tst)
    tests_sweep.append(bs_sweep)
# Out:
# 2016-12-13 13:03:18,698 root         INFO     Testing with bs=5, hs=5:
# 2016-12-13 13:03:18,702 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=5:
# 2016-12-13 13:03:18,703 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:18,705 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:18,707 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:18,708 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:18,709 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:18,777 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:18,832 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:18,884 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:18,925 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:18,963 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:19,000 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:22,301 spike_detect_aux INFO     sv shape (32, 136, 65), target shape (65, 131)
# 2016-12-13 13:03:22,363 spike_detect_aux INFO     k shape (193,)
# 2016-12-13 13:03:22,364 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:22,365 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:22,365 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:22,366 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:22,367 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:22,702 spike_detect_aux INFO     kernel shape (193,), sv_shape (32, 136, 6), len_samples 19503
# 2016-12-13 13:03:22,705 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:22,706 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:22,707 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:22,707 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:22,708 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:22,743 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:22,779 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:22,813 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:22,845 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:22,877 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:22,912 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:26,074 spike_detect_aux INFO     sv shape (32, 136, 65), target shape (65, 131)
# 2016-12-13 13:03:26,142 spike_detect_aux INFO     k shape (193,)
# 2016-12-13 13:03:26,143 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:26,144 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:26,145 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:26,145 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:26,146 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:26,472 spike_detect_aux INFO     kernel shape (193,), sv_shape (32, 136, 6), len_samples 19503
# 2016-12-13 13:03:26,475 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:26,475 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:26,476 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:26,477 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:26,477 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:26,507 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:26,543 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:26,574 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:26,607 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:26,639 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:26,673 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:29,862 spike_detect_aux INFO     sv shape (32, 136, 65), target shape (65, 131)
# 2016-12-13 13:03:29,918 spike_detect_aux INFO     k shape (193,)
# 2016-12-13 13:03:29,919 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:29,920 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:29,921 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:29,921 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:29,922 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:30,251 spike_detect_aux INFO     kernel shape (193,), sv_shape (32, 136, 6), len_samples 19503
# 2016-12-13 13:03:30,254 root         INFO     Testing with bs=5, hs=6:
# 2016-12-13 13:03:30,256 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=6:
# 2016-12-13 13:03:30,256 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:30,257 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:30,258 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:30,259 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:30,259 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:30,295 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:30,330 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:30,360 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:30,391 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:30,425 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:30,458 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:33,644 spike_detect_aux INFO     sv shape (32, 137, 65), target shape (65, 131)
# 2016-12-13 13:03:33,697 spike_detect_aux INFO     k shape (225,)
# 2016-12-13 13:03:33,698 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:33,699 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:33,700 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:33,700 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:33,701 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:34,085 spike_detect_aux INFO     kernel shape (225,), sv_shape (32, 137, 6), len_samples 19503
# 2016-12-13 13:03:34,088 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:34,089 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:34,090 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:34,090 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:34,091 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:34,126 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:34,162 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:34,192 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:34,223 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:34,256 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:34,290 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:37,470 spike_detect_aux INFO     sv shape (32, 137, 65), target shape (65, 131)
# 2016-12-13 13:03:37,563 spike_detect_aux INFO     k shape (225,)
# 2016-12-13 13:03:37,564 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:37,565 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:37,566 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:37,567 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:37,567 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:37,899 spike_detect_aux INFO     kernel shape (225,), sv_shape (32, 137, 6), len_samples 19503
# 2016-12-13 13:03:37,909 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:37,910 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:37,911 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:37,912 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:37,913 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:37,948 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:37,983 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:38,027 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:38,067 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:38,104 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:38,137 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:41,349 spike_detect_aux INFO     sv shape (32, 137, 65), target shape (65, 131)
# 2016-12-13 13:03:41,461 spike_detect_aux INFO     k shape (225,)
# 2016-12-13 13:03:41,462 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:41,462 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:41,463 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:41,464 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:41,465 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:41,794 spike_detect_aux INFO     kernel shape (225,), sv_shape (32, 137, 6), len_samples 19503
# 2016-12-13 13:03:41,800 root         INFO     Testing with bs=5, hs=7:
# 2016-12-13 13:03:41,802 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=7:
# 2016-12-13 13:03:41,803 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:41,804 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:41,804 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:41,805 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:41,806 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:41,843 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:41,878 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:41,908 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:41,939 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:41,969 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:42,000 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:45,238 spike_detect_aux INFO     sv shape (32, 138, 65), target shape (65, 131)
# 2016-12-13 13:03:45,306 spike_detect_aux INFO     k shape (257,)
# 2016-12-13 13:03:45,307 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:45,308 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:45,308 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:45,309 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:45,310 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:45,637 spike_detect_aux INFO     kernel shape (257,), sv_shape (32, 138, 6), len_samples 19503
# 2016-12-13 13:03:45,640 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:45,642 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:45,643 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:45,644 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:45,645 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:45,681 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:45,717 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:45,747 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:45,777 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:45,807 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:45,839 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:49,026 spike_detect_aux INFO     sv shape (32, 138, 65), target shape (65, 131)
# 2016-12-13 13:03:49,095 spike_detect_aux INFO     k shape (257,)
# 2016-12-13 13:03:49,096 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:49,096 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:49,097 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:49,098 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:49,098 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:49,427 spike_detect_aux INFO     kernel shape (257,), sv_shape (32, 138, 6), len_samples 19503
# 2016-12-13 13:03:49,430 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:49,431 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:49,432 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:49,432 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:49,433 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:49,468 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:49,504 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:49,534 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:49,565 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:49,595 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:49,625 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:52,812 spike_detect_aux INFO     sv shape (32, 138, 65), target shape (65, 131)
# 2016-12-13 13:03:53,062 spike_detect_aux INFO     k shape (257,)
# 2016-12-13 13:03:53,063 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:53,063 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:53,064 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:53,065 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:53,066 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:53,391 spike_detect_aux INFO     kernel shape (257,), sv_shape (32, 138, 6), len_samples 19503
# 2016-12-13 13:03:53,394 root         INFO     Testing with bs=5, hs=8:
# 2016-12-13 13:03:53,396 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=8:
# 2016-12-13 13:03:53,397 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:53,397 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:53,398 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:53,399 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:53,400 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:53,435 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:53,471 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:53,501 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:53,532 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:53,562 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:53,594 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:03:56,788 spike_detect_aux INFO     sv shape (32, 139, 65), target shape (65, 131)
# 2016-12-13 13:03:56,945 spike_detect_aux INFO     k shape (289,)
# 2016-12-13 13:03:56,946 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:03:56,947 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:03:56,947 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:03:56,948 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:03:56,949 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:57,281 spike_detect_aux INFO     kernel shape (289,), sv_shape (32, 139, 6), len_samples 19503
# 2016-12-13 13:03:57,283 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:03:57,284 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:03:57,285 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:03:57,286 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:03:57,286 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:03:57,322 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:03:57,358 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:03:57,388 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:03:57,418 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:03:57,449 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:03:57,480 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:00,673 spike_detect_aux INFO     sv shape (32, 139, 65), target shape (65, 131)
# 2016-12-13 13:04:00,759 spike_detect_aux INFO     k shape (289,)
# 2016-12-13 13:04:00,760 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:00,761 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:00,761 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:00,762 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:00,763 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:01,091 spike_detect_aux INFO     kernel shape (289,), sv_shape (32, 139, 6), len_samples 19503
# 2016-12-13 13:04:01,094 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:01,095 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:01,096 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:01,096 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:01,097 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:01,133 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:01,168 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:01,199 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:01,229 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:01,260 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:01,290 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:04,476 spike_detect_aux INFO     sv shape (32, 139, 65), target shape (65, 131)
# 2016-12-13 13:04:04,569 spike_detect_aux INFO     k shape (289,)
# 2016-12-13 13:04:04,570 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:04,571 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:04,572 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:04,572 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:04,573 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:04,908 spike_detect_aux INFO     kernel shape (289,), sv_shape (32, 139, 6), len_samples 19503
# 2016-12-13 13:04:04,918 root         INFO     Testing with bs=5, hs=9:
# 2016-12-13 13:04:04,920 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=9:
# 2016-12-13 13:04:04,921 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:04,922 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:04,922 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:04,923 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:04,924 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:04,960 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:04,995 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:05,025 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:05,055 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:05,086 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:05,117 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:08,354 spike_detect_aux INFO     sv shape (32, 140, 65), target shape (65, 131)
# 2016-12-13 13:04:08,438 spike_detect_aux INFO     k shape (321,)
# 2016-12-13 13:04:08,439 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:08,440 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:08,441 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:08,441 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:08,442 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:08,776 spike_detect_aux INFO     kernel shape (321,), sv_shape (32, 140, 6), len_samples 19503
# 2016-12-13 13:04:08,788 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:08,789 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:08,790 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:08,790 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:08,791 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:08,827 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:08,862 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:08,893 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:08,923 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:08,954 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:08,984 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:12,216 spike_detect_aux INFO     sv shape (32, 140, 65), target shape (65, 131)
# 2016-12-13 13:04:12,316 spike_detect_aux INFO     k shape (321,)
# 2016-12-13 13:04:12,317 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:12,318 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:12,319 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:12,319 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:12,320 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:12,655 spike_detect_aux INFO     kernel shape (321,), sv_shape (32, 140, 6), len_samples 19503
# 2016-12-13 13:04:12,666 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:12,668 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:12,670 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:12,671 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:12,672 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:12,709 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:12,743 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:12,774 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:12,805 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:12,835 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:12,865 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:16,131 spike_detect_aux INFO     sv shape (32, 140, 65), target shape (65, 131)
# 2016-12-13 13:04:16,242 spike_detect_aux INFO     k shape (321,)
# 2016-12-13 13:04:16,243 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:16,244 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:16,245 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:16,245 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:16,246 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:16,577 spike_detect_aux INFO     kernel shape (321,), sv_shape (32, 140, 6), len_samples 19503
# 2016-12-13 13:04:16,589 root         INFO     Testing with bs=5, hs=10:
# 2016-12-13 13:04:16,590 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=10:
# 2016-12-13 13:04:16,591 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:16,592 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:16,593 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:16,593 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:16,594 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:16,630 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:16,665 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:16,695 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:16,726 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:16,757 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:16,788 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:20,071 spike_detect_aux INFO     sv shape (32, 141, 65), target shape (65, 131)
# 2016-12-13 13:04:20,180 spike_detect_aux INFO     k shape (353,)
# 2016-12-13 13:04:20,181 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:20,181 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:20,182 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:20,183 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:20,183 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:20,517 spike_detect_aux INFO     kernel shape (353,), sv_shape (32, 141, 6), len_samples 19503
# 2016-12-13 13:04:20,521 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:20,522 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:20,522 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:20,523 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:20,524 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:20,560 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:20,596 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:20,627 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:20,658 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:20,689 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:20,719 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:23,985 spike_detect_aux INFO     sv shape (32, 141, 65), target shape (65, 131)
# 2016-12-13 13:04:24,104 spike_detect_aux INFO     k shape (353,)
# 2016-12-13 13:04:24,105 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:24,106 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:24,106 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:24,107 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:24,108 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:24,441 spike_detect_aux INFO     kernel shape (353,), sv_shape (32, 141, 6), len_samples 19503
# 2016-12-13 13:04:24,444 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:24,445 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:24,446 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:24,447 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:24,447 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:24,484 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:24,520 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:24,550 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:24,581 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:24,613 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:24,644 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:27,938 spike_detect_aux INFO     sv shape (32, 141, 65), target shape (65, 131)
# 2016-12-13 13:04:28,050 spike_detect_aux INFO     k shape (353,)
# 2016-12-13 13:04:28,051 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:28,052 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:28,052 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:28,053 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:28,054 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:28,388 spike_detect_aux INFO     kernel shape (353,), sv_shape (32, 141, 6), len_samples 19503
# 2016-12-13 13:04:28,400 root         INFO     Testing with bs=5, hs=12:
# 2016-12-13 13:04:28,401 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=12:
# 2016-12-13 13:04:28,402 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:28,403 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:28,404 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:28,404 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:28,405 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:28,442 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:28,477 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:28,508 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:28,540 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:28,572 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:28,603 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:32,011 spike_detect_aux INFO     sv shape (32, 143, 65), target shape (65, 131)
# 2016-12-13 13:04:32,107 spike_detect_aux INFO     k shape (417,)
# 2016-12-13 13:04:32,108 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:32,109 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:32,109 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:32,110 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:32,111 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:32,450 spike_detect_aux INFO     kernel shape (417,), sv_shape (32, 143, 6), len_samples 19503
# 2016-12-13 13:04:32,453 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:32,454 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:32,455 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:32,456 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:32,457 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:32,493 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:32,530 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:32,577 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:32,619 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:32,657 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:32,693 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:36,076 spike_detect_aux INFO     sv shape (32, 143, 65), target shape (65, 131)
# 2016-12-13 13:04:36,139 spike_detect_aux INFO     k shape (417,)
# 2016-12-13 13:04:36,140 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:36,141 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:36,142 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:36,142 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:36,143 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:36,485 spike_detect_aux INFO     kernel shape (417,), sv_shape (32, 143, 6), len_samples 19503
# 2016-12-13 13:04:36,489 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:36,489 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:36,490 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:36,491 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:36,492 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:36,528 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:36,565 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:36,613 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:36,655 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:36,694 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:36,730 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:40,180 spike_detect_aux INFO     sv shape (32, 143, 65), target shape (65, 131)
# 2016-12-13 13:04:40,299 spike_detect_aux INFO     k shape (417,)
# 2016-12-13 13:04:40,300 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:40,301 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:40,301 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:40,302 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:40,303 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:40,645 spike_detect_aux INFO     kernel shape (417,), sv_shape (32, 143, 6), len_samples 19503
# 2016-12-13 13:04:40,648 root         INFO     Testing with bs=5, hs=15:
# 2016-12-13 13:04:40,650 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=15:
# 2016-12-13 13:04:40,651 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:40,652 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:40,652 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:40,653 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:40,654 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:40,691 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:40,728 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:40,760 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:40,792 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:40,825 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:40,857 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:44,267 spike_detect_aux INFO     sv shape (32, 146, 65), target shape (65, 131)
# 2016-12-13 13:04:44,383 spike_detect_aux INFO     k shape (513,)
# 2016-12-13 13:04:44,384 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:44,384 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:44,385 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:44,386 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:44,387 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:44,788 spike_detect_aux INFO     kernel shape (513,), sv_shape (32, 146, 6), len_samples 19503
# 2016-12-13 13:04:44,799 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:44,800 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:44,801 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:44,802 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:44,803 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:44,841 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:44,877 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:44,909 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:44,941 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:44,973 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:45,005 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:48,416 spike_detect_aux INFO     sv shape (32, 146, 65), target shape (65, 131)
# 2016-12-13 13:04:48,576 spike_detect_aux INFO     k shape (513,)
# 2016-12-13 13:04:48,577 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:48,578 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:48,579 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:48,580 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:48,580 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:48,930 spike_detect_aux INFO     kernel shape (513,), sv_shape (32, 146, 6), len_samples 19503
# 2016-12-13 13:04:48,936 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:48,937 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:48,938 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:48,939 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:48,940 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:48,978 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:49,015 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:49,047 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:49,078 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:49,110 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:49,143 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:52,527 spike_detect_aux INFO     sv shape (32, 146, 65), target shape (65, 131)
# 2016-12-13 13:04:52,648 spike_detect_aux INFO     k shape (513,)
# 2016-12-13 13:04:52,649 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:52,650 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:52,651 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:52,652 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:52,653 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:53,008 spike_detect_aux INFO     kernel shape (513,), sv_shape (32, 146, 6), len_samples 19503
# 2016-12-13 13:04:53,012 root         INFO     Testing with bs=5, hs=17:
# 2016-12-13 13:04:53,013 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=17:
# 2016-12-13 13:04:53,014 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:53,015 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:53,016 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:53,017 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:53,018 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:53,055 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:53,093 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:53,125 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:53,157 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:53,189 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:53,221 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:04:56,702 spike_detect_aux INFO     sv shape (32, 148, 65), target shape (65, 131)
# 2016-12-13 13:04:56,852 spike_detect_aux INFO     k shape (577,)
# 2016-12-13 13:04:56,853 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:04:56,854 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:04:56,855 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:04:56,856 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:04:56,856 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:57,211 spike_detect_aux INFO     kernel shape (577,), sv_shape (32, 148, 6), len_samples 19503
# 2016-12-13 13:04:57,216 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:04:57,217 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:04:57,218 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:04:57,219 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:04:57,220 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:04:57,258 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:04:57,295 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:04:57,327 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:04:57,358 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:04:57,390 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:04:57,423 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:00,907 spike_detect_aux INFO     sv shape (32, 148, 65), target shape (65, 131)
# 2016-12-13 13:05:01,041 spike_detect_aux INFO     k shape (577,)
# 2016-12-13 13:05:01,042 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:01,043 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:01,043 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:01,044 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:01,045 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:01,483 spike_detect_aux INFO     kernel shape (577,), sv_shape (32, 148, 6), len_samples 19503
# 2016-12-13 13:05:01,488 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:01,490 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:01,492 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:01,494 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:01,495 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:01,538 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:01,579 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:01,618 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:01,658 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:01,699 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:01,740 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:05,374 spike_detect_aux INFO     sv shape (32, 148, 65), target shape (65, 131)
# 2016-12-13 13:05:05,509 spike_detect_aux INFO     k shape (577,)
# 2016-12-13 13:05:05,511 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:05,512 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:05,513 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:05,514 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:05,516 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:05,912 spike_detect_aux INFO     kernel shape (577,), sv_shape (32, 148, 6), len_samples 19503
# 2016-12-13 13:05:05,916 root         INFO     Testing with bs=5, hs=20:
# 2016-12-13 13:05:05,918 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=20:
# 2016-12-13 13:05:05,919 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:05,920 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:05,921 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:05,922 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:05,922 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:05,963 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:06,001 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:06,034 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:06,068 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:06,101 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:06,135 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:09,711 spike_detect_aux INFO     sv shape (32, 151, 65), target shape (65, 131)
# 2016-12-13 13:05:09,859 spike_detect_aux INFO     k shape (673,)
# 2016-12-13 13:05:09,860 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:09,860 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:09,861 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:09,862 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:09,862 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:10,228 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 151, 6), len_samples 19503
# 2016-12-13 13:05:10,233 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:10,234 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:10,235 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:10,235 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:10,236 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:10,275 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:10,313 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:10,345 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:10,378 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:10,411 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:10,444 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:14,001 spike_detect_aux INFO     sv shape (32, 151, 65), target shape (65, 131)
# 2016-12-13 13:05:14,142 spike_detect_aux INFO     k shape (673,)
# 2016-12-13 13:05:14,143 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:14,144 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:14,145 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:14,145 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:14,146 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:14,512 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 151, 6), len_samples 19503
# 2016-12-13 13:05:14,519 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:14,520 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:14,521 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:14,522 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:14,522 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:14,560 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:14,598 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:14,631 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:14,664 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:14,696 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:14,730 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:18,300 spike_detect_aux INFO     sv shape (32, 151, 65), target shape (65, 131)
# 2016-12-13 13:05:18,441 spike_detect_aux INFO     k shape (673,)
# 2016-12-13 13:05:18,443 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:18,443 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:18,444 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:18,445 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:18,445 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:18,810 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 151, 6), len_samples 19503
# 2016-12-13 13:05:18,816 root         INFO     Testing with bs=5, hs=22:
# 2016-12-13 13:05:18,818 spike_detect_aux INFO     Testing for all pars with bin_size=5, history_size=22:
# 2016-12-13 13:05:18,819 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:18,820 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:18,821 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:18,821 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:18,822 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:18,861 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:18,899 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:18,932 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:18,965 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:18,998 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:19,032 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:22,658 spike_detect_aux INFO     sv shape (32, 153, 65), target shape (65, 131)
# 2016-12-13 13:05:23,006 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:05:23,007 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:23,008 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:23,008 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:23,009 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:23,010 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:23,383 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 153, 6), len_samples 19503
# 2016-12-13 13:05:23,387 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:23,388 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:23,389 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:23,389 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:23,390 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:23,429 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:23,467 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:23,501 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:23,534 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:23,567 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:23,600 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:27,231 spike_detect_aux INFO     sv shape (32, 153, 65), target shape (65, 131)
# 2016-12-13 13:05:27,419 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:05:27,420 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:27,421 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:27,422 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:27,422 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:27,423 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:27,794 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 153, 6), len_samples 19503
# 2016-12-13 13:05:27,799 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:05:27,800 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:05:27,801 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:05:27,802 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:05:27,802 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:27,841 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:05:27,879 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:05:27,913 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:05:27,946 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:05:27,979 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:05:28,012 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:05:31,624 spike_detect_aux INFO     sv shape (32, 153, 65), target shape (65, 131)
# 2016-12-13 13:05:31,782 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:05:31,783 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:05:31,783 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:05:31,784 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:05:31,785 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:05:31,786 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:05:32,159 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 153, 6), len_samples 19503
# 2016-12-13 13:05:32,163 root         INFO     Testing with bs=5, hs=25:
# ...
# 2016-12-13 13:26:51,058 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:26:51,585 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 64, 6), len_samples 19503
# 2016-12-13 13:26:51,587 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:26:51,588 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:26:51,589 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:26:51,590 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:26:51,590 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:26:51,639 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:26:51,683 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:26:51,724 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:26:51,766 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:26:51,807 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:26:51,849 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:26:56,933 spike_detect_aux INFO     sv shape (32, 64, 65), target shape (65, 44)
# 2016-12-13 13:26:58,028 spike_detect_aux INFO     k shape (673,)
# 2016-12-13 13:26:58,029 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:26:58,031 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:26:58,032 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:26:58,033 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:26:58,034 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:26:58,562 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 64, 6), len_samples 19503
# 2016-12-13 13:26:58,564 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:26:58,565 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:26:58,567 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:26:58,568 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:26:58,569 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:26:58,617 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:26:58,663 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:26:58,704 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:26:58,746 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:26:58,788 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:26:58,830 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:03,975 spike_detect_aux INFO     sv shape (32, 64, 65), target shape (65, 44)
# 2016-12-13 13:27:04,990 spike_detect_aux INFO     k shape (673,)
# 2016-12-13 13:27:04,991 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:04,992 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:04,992 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:04,993 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:04,994 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:05,501 spike_detect_aux INFO     kernel shape (673,), sv_shape (32, 64, 6), len_samples 19503
# 2016-12-13 13:27:05,504 root         INFO     Testing with bs=15, hs=22:
# 2016-12-13 13:27:05,505 spike_detect_aux INFO     Testing for all pars with bin_size=15, history_size=22:
# 2016-12-13 13:27:05,506 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:05,508 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:05,510 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:05,511 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:05,512 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:05,566 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:05,612 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:05,696 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:05,757 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:05,809 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:05,882 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:11,347 spike_detect_aux INFO     sv shape (32, 66, 65), target shape (65, 44)
# 2016-12-13 13:27:12,784 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:27:12,785 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:12,786 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:12,786 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:12,787 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:12,788 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:13,366 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 66, 6), len_samples 19503
# 2016-12-13 13:27:13,369 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:13,370 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:13,370 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:13,371 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:13,372 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:13,422 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:13,467 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:13,509 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:13,552 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:13,595 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:13,638 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:19,068 spike_detect_aux INFO     sv shape (32, 66, 65), target shape (65, 44)
# 2016-12-13 13:27:19,776 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:27:19,777 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:19,778 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:19,778 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:19,779 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:19,780 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:20,318 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 66, 6), len_samples 19503
# 2016-12-13 13:27:20,320 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:20,321 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:20,322 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:20,323 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:20,323 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:20,373 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:20,419 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:20,461 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:20,504 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:20,547 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:20,589 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:26,044 spike_detect_aux INFO     sv shape (32, 66, 65), target shape (65, 44)
# 2016-12-13 13:27:27,084 spike_detect_aux INFO     k shape (737,)
# 2016-12-13 13:27:27,085 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:27,085 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:27,086 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:27,087 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:27,088 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:27,646 spike_detect_aux INFO     kernel shape (737,), sv_shape (32, 66, 6), len_samples 19503
# 2016-12-13 13:27:27,649 root         INFO     Testing with bs=15, hs=25:
# 2016-12-13 13:27:27,651 spike_detect_aux INFO     Testing for all pars with bin_size=15, history_size=25:
# 2016-12-13 13:27:27,651 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:27,652 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:27,653 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:27,654 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:27,654 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:27,845 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:28,049 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:28,206 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:28,275 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:28,333 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:28,534 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:34,393 spike_detect_aux INFO     sv shape (32, 69, 65), target shape (65, 44)
# 2016-12-13 13:27:35,116 spike_detect_aux INFO     k shape (833,)
# 2016-12-13 13:27:35,117 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:35,118 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:35,118 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:35,119 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:35,120 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:35,719 spike_detect_aux INFO     kernel shape (833,), sv_shape (32, 69, 6), len_samples 19503
# 2016-12-13 13:27:35,722 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:35,723 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:35,724 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:35,725 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:35,726 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:35,777 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:35,827 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:35,871 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:35,916 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:35,961 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:36,006 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:41,822 spike_detect_aux INFO     sv shape (32, 69, 65), target shape (65, 44)
# 2016-12-13 13:27:43,258 spike_detect_aux INFO     k shape (833,)
# 2016-12-13 13:27:43,259 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:43,260 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:43,261 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:43,261 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:43,262 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:43,841 spike_detect_aux INFO     kernel shape (833,), sv_shape (32, 69, 6), len_samples 19503
# 2016-12-13 13:27:43,844 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:43,845 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:43,845 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:43,846 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:43,847 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:43,899 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:43,946 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:43,990 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:44,035 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:44,079 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:44,124 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:49,930 spike_detect_aux INFO     sv shape (32, 69, 65), target shape (65, 44)
# 2016-12-13 13:27:50,547 spike_detect_aux INFO     k shape (833,)
# 2016-12-13 13:27:50,548 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:50,549 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:50,550 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:50,550 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:50,551 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:51,349 spike_detect_aux INFO     kernel shape (833,), sv_shape (32, 69, 6), len_samples 19503
# 2016-12-13 13:27:51,351 root         INFO     Testing with bs=15, hs=27:
# 2016-12-13 13:27:51,353 spike_detect_aux INFO     Testing for all pars with bin_size=15, history_size=27:
# 2016-12-13 13:27:51,354 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:51,355 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:51,356 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:51,357 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:51,357 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:51,444 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:51,528 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:27:51,598 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:27:51,654 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:27:51,709 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:27:51,776 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:27:58,034 spike_detect_aux INFO     sv shape (32, 71, 65), target shape (65, 44)
# 2016-12-13 13:27:59,216 spike_detect_aux INFO     k shape (897,)
# 2016-12-13 13:27:59,217 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:27:59,218 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:27:59,218 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:27:59,219 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:27:59,220 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:59,866 spike_detect_aux INFO     kernel shape (897,), sv_shape (32, 71, 6), len_samples 19503
# 2016-12-13 13:27:59,876 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:27:59,877 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:27:59,878 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:27:59,879 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:27:59,880 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:27:59,933 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:27:59,980 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:28:00,025 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:28:00,072 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:28:00,117 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:28:00,164 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:28:06,241 spike_detect_aux INFO     sv shape (32, 71, 65), target shape (65, 44)
# 2016-12-13 13:28:06,568 spike_detect_aux INFO     k shape (897,)
# 2016-12-13 13:28:06,569 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:28:06,570 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:28:06,570 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:28:06,571 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:28:06,572 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:28:07,168 spike_detect_aux INFO     kernel shape (897,), sv_shape (32, 71, 6), len_samples 19503
# 2016-12-13 13:28:07,179 spike_detect_aux INFO     Testing fit for a parameter
# 2016-12-13 13:28:07,180 spike_detect_aux INFO     Fitting a kernel
# 2016-12-13 13:28:07,181 spike_detect_aux INFO     Creating support vector 32 chans, 65 trials
# 2016-12-13 13:28:07,181 spike_detect_aux INFO     Collecting 65 frames...
# 2016-12-13 13:28:07,182 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:28:07,235 spike_detect_aux INFO     Frame 10 ...
# 2016-12-13 13:28:07,282 spike_detect_aux INFO     Frame 20 ...
# 2016-12-13 13:28:07,327 spike_detect_aux INFO     Frame 30 ...
# 2016-12-13 13:28:07,372 spike_detect_aux INFO     Frame 40 ...
# 2016-12-13 13:28:07,417 spike_detect_aux INFO     Frame 50 ...
# 2016-12-13 13:28:07,462 spike_detect_aux INFO     Frame 60 ...
# 2016-12-13 13:28:13,529 spike_detect_aux INFO     sv shape (32, 71, 65), target shape (65, 44)
# 2016-12-13 13:28:13,723 spike_detect_aux INFO     k shape (897,)
# 2016-12-13 13:28:13,724 spike_detect_aux INFO     Convolving a kernel
# 2016-12-13 13:28:13,725 spike_detect_aux INFO     Channels are 32
# 2016-12-13 13:28:13,726 spike_detect_aux INFO     Creating support vector 32 chans, 6 trials
# 2016-12-13 13:28:13,727 spike_detect_aux INFO     Collecting 6 frames...
# 2016-12-13 13:28:13,728 spike_detect_aux INFO     Frame 0 ...
# 2016-12-13 13:28:14,596 spike_detect_aux INFO     kernel shape (897,), sv_shape (32, 71, 6), len_samples 19503

# %%
import itertools
n_bs = len(bins)
n_hs = len(histories)
k_par = 1

res_array = np.zeros([n_bs, n_hs, 3])
for b, h in itertools.product(range(n_bs), range(n_hs)):
    res_array[b, h, :] = tests_sweep[b][h][2]
plt.pcolormesh(histories, bins, res_array[:,:,k_par])

# %%
plt.plot(histories, res_array[6,:,k_par])

# %%
os.path.join('tuvieja', 'tar', '')
# Out:
# 'tuvieja/tar/'

# %%
mode = 'w:'
ext = mode.split(':')[-1]

# %%
ext == ''
# Out:
# True

# %%
file_name = '{0}.tar'.format('tuvieja')

# %%
file_name+= '.{0}'.format(ext)

# %%
file_name
# Out:
# 'tuvieja.tar.'
